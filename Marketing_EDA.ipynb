# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
file_name = 'Marketing_Pack.xlsx'

# %%
excel_file = pd.read_excel(file_name, sheet_name=None)

# Automatically create a dataframe variable for every sheet name
for sheet_name, df in excel_file.items():
    globals()[f"{sheet_name}"] = df

# %%
Customer_Master.sample()
# Out:
#      Customer_ID Industry_Segment Region Customer_Type  Years_With_Company  \
# 791  MKT_C100791         Textiles  South        Trader                   4
#
#     Assigned_Sales_Region  Credit_Limit_INR_Lakh  Payment_Terms_Days  \
# 791                    R5                     10                  75
#
#      Strategic_Account_Flag
# 791                       1

# %%
df= Customer_Master.groupby(['Customer_Type','Strategic_Account_Flag']).agg(Accounts = ('Customer_ID','count')).reset_index()
df['Strategic_Account_Flag'] = df['Strategic_Account_Flag'].astype('str')

fig = px.bar(
    df,
    x='Customer_Type',
    y='Accounts',
    color='Strategic_Account_Flag',
    title='Customer_Distribution by Type and Priority'
)

fig.update_layout(
    barmode='stack',
    xaxis_title='Customer_Type',
    yaxis_title='Accounts'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df =  Sales_Transactions.groupby(['Month','Product_Family']).agg(Total_Sales = ('Quantity_MT','sum')).reset_index()
fig = px.line(
    df,
    x='Month',
    y= 'Total_Sales',
    color='Product_Family',
    title='Sensor Trends by Production Line'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df= Customer_Complaints.groupby(['Complaint_Type','Severity']).agg(Accounts = ('Complaint_ID','count')).reset_index()

fig = px.bar(
    df,
    x='Complaint_Type',
    y='Accounts',
    color='Severity',
    title='Complaint Distribution by Type and Severity'
)

fig.update_layout(
    barmode='stack',
    xaxis_title='Complaint_Type',
    yaxis_title='Complaints'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

df = Market_Index.copy()

# Identify all market index columns
index_cols = df.filter(regex="_Index$").columns

fig = go.Figure()

# Add one line for each industry
for col in index_cols:
    fig.add_trace(
        go.Scatter(
            x=df["Month"],
            y=df[col],
            mode="lines+markers",
            name=col.replace("_Index", ""),
            line=dict(width=2),
            marker=dict(size=7)
        )
    )

# Add benchmark line at 100
fig.add_hline(
    y=100,
    line_dash="dash",
    line_width=1.5,
    annotation_text="Benchmark (100)",
    annotation_position="top left"
)

fig.update_layout(
    title="Market Index Trend by Industry",
    xaxis_title="Month",
    yaxis_title="Market Index",
    width=1200,
    height=600,

    # Similar to bbox_to_anchor legend positioning
    legend=dict(
        x=1.02,
        y=1,
        xanchor="left",
        yanchor="top"
    ),

    hovermode="x unified",

    # Similar to plt.grid(True, alpha=0.3)
    xaxis=dict(
        showgrid=True,
        gridcolor="lightgray",
        tickangle=45
    ),
    yaxis=dict(
        showgrid=True,
        gridcolor="lightgray"
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
